# %% [markdown]
# **Dataset: Breast Cancer** :https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html
# - Tập dữ liệu về bệnh ung thư.
# - Có 2 nhãn mắc bệnh và không mắc bệnh.
# - Kích thước: 569x30

# %%
# Import các thư viện cần thiết
import xgboost as xgb
import pandas as pd
import numpy as np

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

# %%
# Load dữ liệu ung thư
X, y = load_breast_cancer(return_X_y=True)
print(X.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
# Chia tập train, test với test_size = 0.1
# Code ở đây:

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (512, 30)
# (512,)
# (57, 30)
# (57,)

# %%
# Tạo đối tượng model XGBoost
clf = xgb.XGBClassifier(tree_method="hist", early_stopping_rounds=2)

# Huấn luyện mô hình
eval_set = [(X_test, y_test)]
clf.fit(X_train, y_train, eval_set=eval_set, verbose=True)

# Dự đoán sử dụng hàm predict
# Code ở đây:

# Đánh giá, in ra sử accuracy_score và classification_report
# Code ở đây:

# %%
# Tối ưu các siêu tham số
# Định nghĩa lưới các siêu tham số
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2]
}

# %%
# Định nghĩa GridSearchCV
#Code ở đây:
grid_search =

# Thực hiện tìm kiếm trên tập huấn luyện
grid_search.fit(X_train, y_train, eval_set=[(X_test, y_test)])

# In ra các siêu tham số tốt nhất
print("Best parameters found: ", grid_search.best_params_)

# Sử dụng mô hình với các siêu tham số tốt nhất để dự đoán trên tập kiểm tra
# Code ở đây:

# Đánh giá, in ra sử accuracy_score và classification_report
# Code ở đây:
